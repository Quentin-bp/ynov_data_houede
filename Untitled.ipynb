# %%
import pandas as pd
import os
os.getcwd ( )
# Out:
# '/Users/enzo/Desktop/YNOV/Data Structuration de Donnee/Projet'

# %%
os.listdir(os.getcwd ( ))
# Out:
# ['exoplanet.csv', 'Untitled.ipynb', '.ipynb_checkpoints']

# %%
df = pd.read_csv('exoplanet.csv')

# %%
df.head()
# Out:
#       pl_name  hostname  default_flag  sy_snum  sy_pnum discoverymethod  \
# 0    AU Mic b    AU Mic             1        1        2         Transit
# 1    AU Mic c    AU Mic             1        1        2         Transit
# 2  DS Tuc A b  DS Tuc A             1        2        1         Transit
# 3   GJ 1252 b   GJ 1252             1        1        1         Transit
# 4    GJ 143 b    GJ 143             1        1        2         Transit
#
#    disc_year                                 disc_facility  \
# 0       2020  Transiting Exoplanet Survey Satellite (TESS)
# 1       2021  Transiting Exoplanet Survey Satellite (TESS)
# 2       2019  Transiting Exoplanet Survey Satellite (TESS)
# 3       2020  Transiting Exoplanet Survey Satellite (TESS)
# 4       2019  Transiting Exoplanet Survey Satellite (TESS)
#
#                soltype  pl_controv_flag  ... sy_vmagerr2  sy_kmag  \
# 0  Published Confirmed                0  ...       -0.10    4.529
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# pl_name           0.0
# hostname          0.0
# default_flag      0.0
# sy_snum           0.0
# sy_pnum           0.0
#                  ...
# sy_gaiamagerr1    0.0
# sy_gaiamagerr2    0.0
# rowupdate         0.0
# pl_pubdate        0.0
# releasedate       0.0
# Length: 92, dtype: float64

# %%
df.describe(include='all')
# Out:
#          pl_name hostname  default_flag     sy_snum     sy_pnum  \
# count        273      273         273.0  273.000000  273.000000
# unique       273      205           NaN         NaN         NaN
# top     AU Mic b  TOI-561           NaN         NaN         NaN
# freq           1        5           NaN         NaN         NaN
# mean         NaN      NaN           1.0    1.157509    1.934066
# std          NaN      NaN           0.0    0.412253    1.324005
# min          NaN      NaN           1.0    1.000000    1.000000
# 25%          NaN      NaN           1.0    1.000000    1.000000
# 50%          NaN      NaN           1.0    1.000000    1.000000
# 75%          NaN      NaN           1.0    1.000000    2.000000
# max          NaN      NaN           1.0    3.000000    6.000000
#
#        discoverymethod    disc_year  \
# count              273   273.000000
# unique               3          NaN
# top            Transit          NaN
# freq               269          NaN
# ...

# %%
import seaborn as sns
sns.boxplot(df['sy_dist'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sy_dist'>

# %%
import numpy as np

# %%
exoplanet = df[df['sy_dist'] < 50]

# %%
exoplanet.pivot( columns='pl_name', values='sy_dist')
# Out:
# pl_name  AU Mic b  AU Mic c  DS Tuc A b  GJ 1252 b  GJ 143 b  GJ 3090 b  \
# 0          9.7221       NaN         NaN        NaN       NaN        NaN
# 1             NaN    9.7221         NaN        NaN       NaN        NaN
# 2             NaN       NaN     44.0622        NaN       NaN        NaN
# 3             NaN       NaN         NaN     20.373       NaN        NaN
# 4             NaN       NaN         NaN        NaN     16.32        NaN
# ..            ...       ...         ...        ...       ...        ...
# 255           NaN       NaN         NaN        NaN       NaN        NaN
# 256           NaN       NaN         NaN        NaN       NaN        NaN
# 259           NaN       NaN         NaN        NaN       NaN        NaN
# 271           NaN       NaN         NaN        NaN       NaN        NaN
# 272           NaN       NaN         NaN        NaN       NaN        NaN
#
# pl_name  GJ 3473 b  GJ 357 b  GJ 367 b  GJ 3929 b  ...  TOI-620 b  TOI-674 b  \
# ...

# %%
sns.boxplot(exoplanet['sy_dist'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sy_dist'>

# %%
sns.stripplot(data=exoplanet, x="sy_dist")
# Out:
# <AxesSubplot:xlabel='sy_dist'>

# %%
exoplanet.describe(include='all')
# Out:
#          pl_name  hostname  default_flag    sy_snum    sy_pnum  \
# count         93        93          93.0  93.000000  93.000000
# unique        93        64           NaN        NaN        NaN
# top     AU Mic b  HD 23472           NaN        NaN        NaN
# freq           1         5           NaN        NaN        NaN
# mean         NaN       NaN           1.0   1.204301   2.053763
# std          NaN       NaN           0.0   0.479110   1.106950
# min          NaN       NaN           1.0   1.000000   1.000000
# 25%          NaN       NaN           1.0   1.000000   1.000000
# 50%          NaN       NaN           1.0   1.000000   2.000000
# 75%          NaN       NaN           1.0   1.000000   3.000000
# max          NaN       NaN           1.0   3.000000   5.000000
#
#        discoverymethod    disc_year  \
# count               93    93.000000
# unique               2          NaN
# top            Transit          NaN
# freq                92          NaN
# ...
